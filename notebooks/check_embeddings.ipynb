# %% [markdown]
# # GIST Embeddings

# %%
import torch
from pathlib import Path

# Load any saved embedding
embedding_file = Path("C:/Users/cahel/Desktop/Med3Tab-PFN/SAM-Med3D-main/SAM-Med3D-main/features/gist/ct_GIST_train/GIST-001_CT.nii_embedding.pt")
data = torch.load(embedding_file, map_location='cpu')

emb = data['embedding']

print(f"Embedding shape: {emb.shape}")
# Out:
# Embedding shape: torch.Size([1, 384, 8, 8, 8])

# %% [markdown]
# # Lipo Embeddings

# %%
import torch
from pathlib import Path

# Load any saved embedding
embedding_file = Path("C:/Users/cahel/Desktop/Med3Tab-PFN/SAM-Med3D-main/SAM-Med3D-main/features/lipo/ct_LIPO_train/LIPO-001_MR.nii_embedding.pt")
data = torch.load(embedding_file, map_location='cpu')

emb = data['embedding']

print(f"Embedding shape: {emb.shape}")
# Out:
# Embedding shape: torch.Size([1, 384, 8, 8, 8])
